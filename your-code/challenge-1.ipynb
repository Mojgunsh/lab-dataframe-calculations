# %% [markdown]
# # Challenge 1
#
# In this challenge you will be working on **Pokemon**. You will answer a series of questions in order to practice dataframe calculation, aggregation, and transformation.
#
# ![Pokemon](../images/pokemon.jpg)
#
# Follow the instructions below and enter your code.
#
# #### Import all required libraries.

# %%
# import libraries
import pandas as pd
import numpy as np
import re

# %% [markdown]
# #### Import data set.
#
# Read the dataset `pokemon.csv` into a dataframe called `pokemon`.
#
# *Data set attributed to [Alberto Barradas](https://www.kaggle.com/abcsds/pokemon/)*

# %%
# import dataset
pokemon=pd.read_csv('pokemon.csv')

# %% [markdown]
# #### Print first 10 rows of `pokemon`.

# %%
# your code here
pokemon.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False
# 9       50       64     43           1      False

# %% [markdown]
# When you look at a data set, you often wonder what each column means. Some open-source data sets provide descriptions of the data set. In many cases, data descriptions are extremely useful for data analysts to perform work efficiently and successfully.
#
# For the `Pokemon.csv` data set, fortunately, the owner provided descriptions which you can see [here](https://www.kaggle.com/abcsds/pokemon/home). For your convenience, we are including the descriptions below. Read the descriptions and understand what each column means. This knowledge is helpful in your work with the data.
#
# | Column | Description |
# | --- | --- |
# | # | ID for each pokemon |
# | Name | Name of each pokemon |
# | Type 1 | Each pokemon has a type, this determines weakness/resistance to attacks |
# | Type 2 | Some pokemon are dual type and have 2 |
# | Total | A general guide to how strong a pokemon is |
# | HP | Hit points, or health, defines how much damage a pokemon can withstand before fainting |
# | Attack | The base modifier for normal attacks (eg. Scratch, Punch) |
# | Defense | The base damage resistance against normal attacks |
# | SP Atk | Special attack, the base modifier for special attacks (e.g. fire blast, bubble beam) |
# | SP Def | The base damage resistance against special attacks |
# | Speed | Determines which pokemon attacks first each round |
# | Generation | Number of generation |
# | Legendary | True if Legendary Pokemon False if not |

# %% [markdown]
# #### Obtain the distinct values across `Type 1` and `Type 2`.
#
# Exctract all the values in `Type 1` and `Type 2`. Then create an array containing the distinct values across both fields.

# %%
# your code here
pokemon['Type 1'].value_counts()
pokemon['Type 2'].value_counts()
lst1=pokemon['Type 1']
lst2=pokemon['Type 2']
lst3 = [[i] + [j] for (i, j) in zip(lst1, lst2)] 
display(lst3)

#for i in range(len(lst1)):
 #   lst3=zip(str(lst1[i])+str(lst2[i]))
# Out:
# [['Grass', 'Poison'],
#  ['Grass', 'Poison'],
#  ['Grass', 'Poison'],
#  ['Grass', 'Poison'],
#  ['Fire', nan],
#  ['Fire', nan],
#  ['Fire', 'Flying'],
#  ['Fire', 'Dragon'],
#  ['Fire', 'Flying'],
#  ['Water', nan],
#  ['Water', nan],
#  ['Water', nan],
#  ['Water', nan],
#  ['Bug', nan],
#  ['Bug', nan],
#  ['Bug', 'Flying'],
#  ['Bug', 'Poison'],
#  ['Bug', 'Poison'],
#  ['Bug', 'Poison'],
#  ['Bug', 'Poison'],
#  ['Normal', 'Flying'],
#  ['Normal', 'Flying'],
#  ['Normal', 'Flying'],
#  ['Normal', 'Flying'],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Normal', 'Flying'],
#  ['Normal', 'Flying'],
#  ['Poison', nan],
#  ['Poison', nan],
#  ['Electric', nan],
#  ['Electric', nan],
#  ['Ground', nan],
#  ['Ground', nan],
#  ['Poison', nan],
#  ['Poison', nan],
#  ['Poison', 'Ground'],
#  ['Poison', nan],
#  ['Poison', nan],
#  ['Poison', 'Ground'],
#  ['Fairy', nan],
#  ['Fairy', nan],
#  ['Fire', nan],
#  ['Fire', nan],
#  ['Normal', 'Fairy'],
#  ['Normal', 'Fairy'],
#  ['Poison', 'Flying'],
#  ['Poison', 'Flying'],
#  ['Grass', 'Poison'],
#  ['Grass', 'Poison'],
#  ['Grass', 'Poison'],
#  ['Bug', 'Grass'],
#  ['Bug', 'Grass'],
#  ['Bug', 'Poison'],
#  ['Bug', 'Poison'],
#  ['Ground', nan],
#  ['Ground', nan],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Water', nan],
#  ['Water', nan],
#  ['Fighting', nan],
#  ['Fighting', nan],
#  ['Fire', nan],
#  ['Fire', nan],
#  ['Water', nan],
#  ['Water', nan],
#  ['Water', 'Fighting'],
#  ['Psychic', nan],
#  ['Psychic', nan],
#  ['Psychic', nan],
#  ['Psychic', nan],
#  ['Fighting', nan],
#  ['Fighting', nan],
#  ['Fighting', nan],
#  ['Grass', 'Poison'],
#  ['Grass', 'Poison'],
#  ['Grass', 'Poison'],
#  ['Water', 'Poison'],
#  ['Water', 'Poison'],
#  ['Rock', 'Ground'],
#  ['Rock', 'Ground'],
#  ['Rock', 'Ground'],
#  ['Fire', nan],
#  ['Fire', nan],
#  ['Water', 'Psychic'],
#  ['Water', 'Psychic'],
#  ['Water', 'Psychic'],
#  ['Electric', 'Steel'],
#  ['Electric', 'Steel'],
#  ['Normal', 'Flying'],
#  ['Normal', 'Flying'],
#  ['Normal', 'Flying'],
#  ['Water', nan],
#  ['Water', 'Ice'],
#  ['Poison', nan],
#  ['Poison', nan],
#  ['Water', nan],
#  ['Water', 'Ice'],
#  ['Ghost', 'Poison'],
#  ['Ghost', 'Poison'],
#  ['Ghost', 'Poison'],
#  ['Ghost', 'Poison'],
#  ['Rock', 'Ground'],
#  ['Psychic', nan],
#  ['Psychic', nan],
#  ['Water', nan],
#  ['Water', nan],
#  ['Electric', nan],
#  ['Electric', nan],
#  ['Grass', 'Psychic'],
#  ['Grass', 'Psychic'],
#  ['Ground', nan],
#  ['Ground', nan],
#  ['Fighting', nan],
#  ['Fighting', nan],
#  ['Normal', nan],
#  ['Poison', nan],
#  ['Poison', nan],
#  ['Ground', 'Rock'],
#  ['Ground', 'Rock'],
#  ['Normal', nan],
#  ['Grass', nan],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Water', nan],
#  ['Water', nan],
#  ['Water', nan],
#  ['Water', nan],
#  ['Water', nan],
#  ['Water', 'Psychic'],
#  ['Psychic', 'Fairy'],
#  ['Bug', 'Flying'],
#  ['Ice', 'Psychic'],
#  ['Electric', nan],
#  ['Fire', nan],
#  ['Bug', nan],
#  ['Bug', 'Flying'],
#  ['Normal', nan],
#  ['Water', nan],
#  ['Water', 'Flying'],
#  ['Water', 'Dark'],
#  ['Water', 'Ice'],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Water', nan],
#  ['Electric', nan],
#  ['Fire', nan],
#  ['Normal', nan],
#  ['Rock', 'Water'],
#  ['Rock', 'Water'],
#  ['Rock', 'Water'],
#  ['Rock', 'Water'],
#  ['Rock', 'Flying'],
#  ['Rock', 'Flying'],
#  ['Normal', nan],
#  ['Ice', 'Flying'],
#  ['Electric', 'Flying'],
#  ['Fire', 'Flying'],
#  ['Dragon', nan],
#  ['Dragon', nan],
#  ['Dragon', 'Flying'],
#  ['Psychic', nan],
#  ['Psychic', 'Fighting'],
#  ['Psychic', nan],
#  ['Psychic', nan],
#  ['Grass', nan],
#  ['Grass', nan],
#  ['Grass', nan],
#  ['Fire', nan],
#  ['Fire', nan],
#  ['Fire', nan],
#  ['Water', nan],
#  ['Water', nan],
#  ['Water', nan],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Normal', 'Flying'],
#  ['Normal', 'Flying'],
#  ['Bug', 'Flying'],
#  ['Bug', 'Flying'],
#  ['Bug', 'Poison'],
#  ['Bug', 'Poison'],
#  ['Poison', 'Flying'],
#  ['Water', 'Electric'],
#  ['Water', 'Electric'],
#  ['Electric', nan],
#  ['Fairy', nan],
#  ['Normal', 'Fairy'],
#  ['Fairy', nan],
#  ['Fairy', 'Flying'],
#  ['Psychic', 'Flying'],
#  ['Psychic', 'Flying'],
#  ['Electric', nan],
#  ['Electric', nan],
#  ['Electric', nan],
#  ['Electric', 'Dragon'],
#  ['Grass', nan],
#  ['Water', 'Fairy'],
#  ['Water', 'Fairy'],
#  ['Rock', nan],
#  ['Water', nan],
#  ['Grass', 'Flying'],
#  ['Grass', 'Flying'],
#  ['Grass', 'Flying'],
#  ['Normal', nan],
#  ['Grass', nan],
#  ['Grass', nan],
#  ['Bug', 'Flying'],
#  ['Water', 'Ground'],
#  ['Water', 'Ground'],
#  ['Psychic', nan],
#  ['Dark', nan],
#  ['Dark', 'Flying'],
#  ['Water', 'Psychic'],
#  ['Ghost', nan],
#  ['Psychic', nan],
#  ['Psychic', nan],
#  ['Normal', 'Psychic'],
#  ['Bug', nan],
#  ['Bug', 'Steel'],
#  ['Normal', nan],
#  ['Ground', 'Flying'],
#  ['Steel', 'Ground'],
#  ['Steel', 'Ground'],
#  ['Fairy', nan],
#  ['Fairy', nan],
#  ['Water', 'Poison'],
#  ['Bug', 'Steel'],
#  ['Bug', 'Steel'],
#  ['Bug', 'Rock'],
#  ['Bug', 'Fighting'],
#  ['Bug', 'Fighting'],
#  ['Dark', 'Ice'],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Fire', nan],
#  ['Fire', 'Rock'],
#  ['Ice', 'Ground'],
#  ['Ice', 'Ground'],
#  ['Water', 'Rock'],
#  ['Water', nan],
#  ['Water', nan],
#  ['Ice', 'Flying'],
#  ['Water', 'Flying'],
#  ['Steel', 'Flying'],
#  ['Dark', 'Fire'],
#  ['Dark', 'Fire'],
#  ['Dark', 'Fire'],
#  ['Water', 'Dragon'],
#  ['Ground', nan],
#  ['Ground', nan],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Fighting', nan],
#  ['Fighting', nan],
#  ['Ice', 'Psychic'],
#  ['Electric', nan],
#  ['Fire', nan],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Electric', nan],
#  ['Fire', nan],
#  ['Water', nan],
#  ['Rock', 'Ground'],
#  ['Rock', 'Ground'],
#  ['Rock', 'Dark'],
#  ['Rock', 'Dark'],
#  ['Psychic', 'Flying'],
#  ['Fire', 'Flying'],
#  ['Psychic', 'Grass'],
#  ['Grass', nan],
#  ['Grass', nan],
#  ['Grass', nan],
#  ['Grass', 'Dragon'],
#  ['Fire', nan],
#  ['Fire', 'Fighting'],
#  ['Fire', 'Fighting'],
#  ['Fire', 'Fighting'],
#  ['Water', nan],
#  ['Water', 'Ground'],
#  ['Water', 'Ground'],
#  ['Water', 'Ground'],
#  ['Dark', nan],
#  ['Dark', nan],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Bug', nan],
#  ['Bug', nan],
#  ['Bug', 'Flying'],
#  ['Bug', nan],
#  ['Bug', 'Poison'],
#  ['Water', 'Grass'],
#  ['Water', 'Grass'],
#  ['Water', 'Grass'],
#  ['Grass', nan],
#  ['Grass', 'Dark'],
#  ['Grass', 'Dark'],
#  ['Normal', 'Flying'],
#  ['Normal', 'Flying'],
#  ['Water', 'Flying'],
#  ['Water', 'Flying'],
#  ['Psychic', 'Fairy'],
#  ['Psychic', 'Fairy'],
#  ['Psychic', 'Fairy'],
#  ['Psychic', 'Fairy'],
#  ['Bug', 'Water'],
#  ['Bug', 'Flying'],
#  ['Grass', nan],
#  ['Grass', 'Fighting'],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Bug', 'Ground'],
#  ['Bug', 'Flying'],
#  ['Bug', 'Ghost'],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Fighting', nan],
#  ['Fighting', nan],
#  ['Normal', 'Fairy'],
#  ['Rock', nan],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Dark', 'Ghost'],
#  ['Dark', 'Ghost'],
#  ['Steel', 'Fairy'],
#  ['Steel', 'Fairy'],
#  ['Steel', 'Rock'],
#  ['Steel', 'Rock'],
#  ['Steel', 'Rock'],
#  ['Steel', nan],
#  ['Fighting', 'Psychic'],
#  ['Fighting', 'Psychic'],
#  ['Fighting', 'Psychic'],
#  ['Electric', nan],
#  ['Electric', nan],
#  ['Electric', nan],
#  ['Electric', nan],
#  ['Electric', nan],
#  ['Bug', nan],
#  ['Bug', nan],
#  ['Grass', 'Poison'],
#  ['Poison', nan],
#  ['Poison', nan],
#  ['Water', 'Dark'],
#  ['Water', 'Dark'],
#  ['Water', 'Dark'],
#  ['Water', nan],
#  ['Water', nan],
#  ['Fire', 'Ground'],
#  ['Fire', 'Ground'],
#  ['Fire', 'Ground'],
#  ['Fire', nan],
#  ['Psychic', nan],
#  ['Psychic', nan],
#  ['Normal', nan],
#  ['Ground', nan],
#  ['Ground', 'Dragon'],
#  ['Ground', 'Dragon'],
#  ['Grass', nan],
#  ['Grass', 'Dark'],
#  ['Normal', 'Flying'],
#  ['Dragon', 'Flying'],
#  ['Dragon', 'Fairy'],
#  ['Normal', nan],
#  ['Poison', nan],
#  ['Rock', 'Psychic'],
#  ['Rock', 'Psychic'],
#  ['Water', 'Ground'],
#  ['Water', 'Ground'],
#  ['Water', nan],
#  ['Water', 'Dark'],
#  ['Ground', 'Psychic'],
#  ['Ground', 'Psychic'],
#  ['Rock', 'Grass'],
#  ['Rock', 'Grass'],
#  ['Rock', 'Bug'],
#  ['Rock', 'Bug'],
#  ['Water', nan],
#  ['Water', nan],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Ghost', nan],
#  ['Ghost', nan],
#  ['Ghost', nan],
#  ['Ghost', nan],
#  ['Ghost', nan],
#  ['Grass', 'Flying'],
#  ['Psychic', nan],
#  ['Dark', nan],
#  ['Dark', nan],
#  ['Psychic', nan],
#  ['Ice', nan],
#  ['Ice', nan],
#  ['Ice', nan],
#  ['Ice', 'Water'],
#  ['Ice', 'Water'],
#  ['Ice', 'Water'],
#  ['Water', nan],
#  ['Water', nan],
#  ['Water', nan],
#  ['Water', 'Rock'],
#  ['Water', nan],
#  ['Dragon', nan],
#  ['Dragon', nan],
#  ['Dragon', 'Flying'],
#  ['Dragon', 'Flying'],
#  ['Steel', 'Psychic'],
#  ['Steel', 'Psychic'],
#  ['Steel', 'Psychic'],
#  ['Steel', 'Psychic'],
#  ['Rock', nan],
#  ['Ice', nan],
#  ['Steel', nan],
#  ['Dragon', 'Psychic'],
#  ['Dragon', 'Psychic'],
#  ['Dragon', 'Psychic'],
#  ['Dragon', 'Psychic'],
#  ['Water', nan],
#  ['Water', nan],
#  ['Ground', nan],
#  ['Ground', 'Fire'],
#  ['Dragon', 'Flying'],
#  ['Dragon', 'Flying'],
#  ['Steel', 'Psychic'],
#  ['Psychic', nan],
#  ['Psychic', nan],
#  ['Psychic', nan],
#  ['Psychic', nan],
#  ['Grass', nan],
#  ['Grass', nan],
#  ['Grass', 'Ground'],
#  ['Fire', nan],
#  ['Fire', 'Fighting'],
#  ['Fire', 'Fighting'],
#  ['Water', nan],
#  ['Water', nan],
#  ['Water', 'Steel'],
#  ['Normal', 'Flying'],
#  ['Normal', 'Flying'],
#  ['Normal', 'Flying'],
#  ['Normal', nan],
#  ['Normal', 'Water'],
#  ['Bug', nan],
#  ['Bug', nan],
#  ['Electric', nan],
#  ['Electric', nan],
#  ['Electric', nan],
#  ['Grass', 'Poison'],
#  ['Grass', 'Poison'],
#  ['Rock', nan],
#  ['Rock', nan],
#  ['Rock', 'Steel'],
#  ['Rock', 'Steel'],
#  ['Bug', nan],
#  ['Bug', 'Grass'],
#  ['Bug', 'Ground'],
#  ['Bug', 'Steel'],
#  ['Bug', 'Flying'],
#  ['Bug', 'Flying'],
#  ['Bug', 'Flying'],
#  ['Electric', nan],
#  ['Water', nan],
#  ['Water', nan],
#  ['Grass', nan],
#  ['Grass', nan],
#  ['Water', nan],
#  ['Water', 'Ground'],
#  ['Normal', nan],
#  ['Ghost', 'Flying'],
#  ['Ghost', 'Flying'],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Normal', 'Fighting'],
#  ['Ghost', nan],
#  ['Dark', 'Flying'],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Psychic', nan],
#  ['Poison', 'Dark'],
#  ['Poison', 'Dark'],
#  ['Steel', 'Psychic'],
#  ['Steel', 'Psychic'],
#  ['Rock', nan],
#  ['Psychic', 'Fairy'],
#  ['Normal', nan],
#  ['Normal', 'Flying'],
#  ['Ghost', 'Dark'],
#  ['Dragon', 'Ground'],
#  ['Dragon', 'Ground'],
#  ['Dragon', 'Ground'],
#  ['Dragon', 'Ground'],
#  ['Normal', nan],
#  ['Fighting', nan],
#  ['Fighting', 'Steel'],
#  ['Fighting', 'Steel'],
#  ['Ground', nan],
#  ['Ground', nan],
#  ['Poison', 'Bug'],
#  ['Poison', 'Dark'],
#  ['Poison', 'Fighting'],
#  ['Poison', 'Fighting'],
#  ['Grass', nan],
#  ['Water', nan],
#  ['Water', nan],
#  ['Water', 'Flying'],
#  ['Grass', 'Ice'],
#  ['Grass', 'Ice'],
#  ['Grass', 'Ice'],
#  ['Dark', 'Ice'],
#  ['Electric', 'Steel'],
#  ['Normal', nan],
#  ['Ground', 'Rock'],
#  ['Grass', nan],
#  ['Electric', nan],
#  ['Fire', nan],
#  ['Fairy', 'Flying'],
#  ['Bug', 'Flying'],
#  ['Grass', nan],
#  ['Ice', nan],
#  ['Ground', 'Flying'],
#  ['Ice', 'Ground'],
#  ['Normal', nan],
#  ['Psychic', 'Fighting'],
#  ['Psychic', 'Fighting'],
#  ['Rock', 'Steel'],
#  ['Ghost', nan],
#  ['Ice', 'Ghost'],
#  ['Electric', 'Ghost'],
#  ['Electric', 'Fire'],
#  ['Electric', 'Water'],
#  ['Electric', 'Ice'],
#  ['Electric', 'Flying'],
#  ['Electric', 'Grass'],
#  ['Psychic', nan],
#  ['Psychic', nan],
#  ['Psychic', nan],
#  ['Steel', 'Dragon'],
#  ['Water', 'Dragon'],
#  ['Fire', 'Steel'],
#  ['Normal', nan],
#  ['Ghost', 'Dragon'],
#  ['Ghost', 'Dragon'],
#  ['Psychic', nan],
#  ['Water', nan],
#  ['Water', nan],
#  ['Dark', nan],
#  ['Grass', nan],
#  ['Grass', 'Flying'],
#  ['Normal', nan],
#  ['Psychic', 'Fire'],
#  ['Grass', nan],
#  ['Grass', nan],
#  ['Grass', nan],
#  ['Fire', nan],
#  ['Fire', 'Fighting'],
#  ['Fire', 'Fighting'],
#  ['Water', nan],
#  ['Water', nan],
#  ['Water', nan],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Dark', nan],
#  ['Dark', nan],
#  ['Grass', nan],
#  ['Grass', nan],
#  ['Fire', nan],
#  ['Fire', nan],
#  ['Water', nan],
#  ['Water', nan],
#  ['Psychic', nan],
#  ['Psychic', nan],
#  ['Normal', 'Flying'],
#  ['Normal', 'Flying'],
#  ['Normal', 'Flying'],
#  ['Electric', nan],
#  ['Electric', nan],
#  ['Rock', nan],
#  ['Rock', nan],
#  ['Rock', nan],
#  ['Psychic', 'Flying'],
#  ['Psychic', 'Flying'],
#  ['Ground', nan],
#  ['Ground', 'Steel'],
#  ['Normal', nan],
#  ['Normal', 'Fairy'],
#  ['Fighting', nan],
#  ['Fighting', nan],
#  ['Fighting', nan],
#  ['Water', nan],
#  ['Water', 'Ground'],
#  ['Water', 'Ground'],
#  ['Fighting', nan],
#  ['Fighting', nan],
#  ['Bug', 'Grass'],
#  ['Bug', 'Grass'],
#  ['Bug', 'Grass'],
#  ['Bug', 'Poison'],
#  ['Bug', 'Poison'],
#  ['Bug', 'Poison'],
#  ['Grass', 'Fairy'],
#  ['Grass', 'Fairy'],
#  ['Grass', nan],
#  ['Grass', nan],
#  ['Water', nan],
#  ['Ground', 'Dark'],
#  ['Ground', 'Dark'],
#  ['Ground', 'Dark'],
#  ['Fire', nan],
#  ['Fire', nan],
#  ['Fire', 'Psychic'],
#  ['Grass', nan],
#  ['Bug', 'Rock'],
#  ['Bug', 'Rock'],
#  ['Dark', 'Fighting'],
#  ['Dark', 'Fighting'],
#  ['Psychic', 'Flying'],
#  ['Ghost', nan],
#  ['Ghost', nan],
#  ['Water', 'Rock'],
#  ['Water', 'Rock'],
#  ['Rock', 'Flying'],
#  ['Rock', 'Flying'],
#  ['Poison', nan],
#  ['Poison', nan],
#  ['Dark', nan],
#  ['Dark', nan],
#  ['Normal', nan],
#  ['Normal', nan],
#  ['Psychic', nan],
#  ['Psychic', nan],
#  ['Psychic', nan],
#  ['Psychic', nan],
#  ['Psychic', nan],
#  ['Psychic', nan],
#  ['Water', 'Flying'],
#  ['Water', 'Flying'],
#  ['Ice', nan],
#  ['Ice', nan],
#  ['Ice', nan],
#  ['Normal', 'Grass'],
#  ['Normal', 'Grass'],
#  ['Electric', 'Flying'],
#  ['Bug', nan],
#  ['Bug', 'Steel'],
#  ['Grass', 'Poison'],
#  ['Grass', 'Poison'],
#  ['Water', 'Ghost'],
#  ['Water', 'Ghost'],
#  ['Water', nan],
#  ['Bug', 'Electric'],
#  ['Bug', 'Electric'],
#  ['Grass', 'Steel'],
#  ['Grass', 'Steel'],
#  ['Steel', nan],
#  ['Steel', nan],
#  ['Steel', nan],
#  ['Electric', nan],
#  ['Electric', nan],
#  ['Electric', nan],
#  ['Psychic', nan],
#  ['Psychic', nan],
#  ['Ghost', 'Fire'],
#  ['Ghost', 'Fire'],
#  ['Ghost', 'Fire'],
#  ['Dragon', nan],
#  ['Dragon', nan],
#  ['Dragon', nan],
#  ['Ice', nan],
#  ['Ice', nan],
#  ['Ice', nan],
#  ['Bug', nan],
#  ['Bug', nan],
#  ['Ground', 'Electric'],
#  ['Fighting', nan],
#  ['Fighting', nan],
#  ['Dragon', nan],
#  ['Ground', 'Ghost'],
#  ['Ground', 'Ghost'],
#  ['Dark', 'Steel'],
#  ['Dark', 'Steel'],
#  ['Normal', nan],
#  ['Normal', 'Flying'],
#  ['Normal', 'Flying'],
#  ['Dark', 'Flying'],
#  ['Dark', 'Flying'],
#  ['Fire', nan],
#  ['Bug', 'Steel'],
#  ['Dark', 'Dragon'],
#  ['Dark', 'Dragon'],
#  ['Dark', 'Dragon'],
#  ['Bug', 'Fire'],
#  ['Bug', 'Fire'],
#  ['Steel', 'Fighting'],
#  ['Rock', 'Fighting'],
#  ['Grass', 'Fighting'],
#  ['Flying', nan],
#  ['Flying', nan],
#  ['Electric', 'Flying'],
#  ['Electric', 'Flying'],
#  ['Dragon', 'Fire'],
#  ['Dragon', 'Electric'],
#  ['Ground', 'Flying'],
#  ['Ground', 'Flying'],
#  ['Dragon', 'Ice'],
#  ['Dragon', 'Ice'],
#  ['Dragon', 'Ice'],
#  ['Water', 'Fighting'],
#  ['Water', 'Fighting'],
#  ['Normal', 'Psychic'],
#  ['Normal', 'Fighting'],
#  ['Bug', 'Steel'],
#  ['Grass', nan],
#  ['Grass', nan],
#  ['Grass', 'Fighting'],
#  ['Fire', nan],
#  ['Fire', nan],
#  ['Fire', 'Psychic'],
#  ['Water', nan],
#  ['Water', nan],
#  ['Water', 'Dark'],
#  ['Normal', nan],
#  ['Normal', 'Ground'],
#  ['Normal', 'Flying'],
#  ['Fire', 'Flying'],
#  ['Fire', 'Flying'],
#  ['Bug', nan],
#  ['Bug', nan],
#  ['Bug', 'Flying'],
#  ['Fire', 'Normal'],
#  ['Fire', 'Normal'],
#  ['Fairy', nan],
#  ['Fairy', nan],
#  ['Fairy', nan],
#  ['Grass', nan],
#  ['Grass', nan],
#  ['Fighting', nan],
#  ['Fighting', 'Dark'],
#  ['Normal', nan],
#  ['Psychic', nan],
#  ['Psychic', nan],
#  ['Psychic', nan],
#  ['Steel', 'Ghost'],
#  ['Steel', 'Ghost'],
#  ['Steel', 'Ghost'],
#  ['Steel', 'Ghost'],
#  ['Fairy', nan],
#  ['Fairy', nan],
#  ['Fairy', nan],
#  ['Fairy', nan],
#  ['Dark', 'Psychic'],
#  ['Dark', 'Psychic'],
#  ['Rock', 'Water'],
#  ['Rock', 'Water'],
#  ['Poison', 'Water'],
#  ['Poison', 'Dragon'],
#  ['Water', nan],
#  ['Water', nan],
#  ['Electric', 'Normal'],
#  ['Electric', 'Normal'],
#  ['Rock', 'Dragon'],
#  ['Rock', 'Dragon'],
#  ['Rock', 'Ice'],
#  ['Rock', 'Ice'],
#  ['Fairy', nan],
#  ['Fighting', 'Flying'],
#  ['Electric', 'Fairy'],
#  ['Rock', 'Fairy'],
#  ['Dragon', nan],
#  ['Dragon', nan],
#  ['Dragon', nan],
#  ['Steel', 'Fairy'],
#  ['Ghost', 'Grass'],
#  ['Ghost', 'Grass'],
#  ['Ghost', 'Grass'],
#  ['Ghost', 'Grass'],
#  ['Ghost', 'Grass'],
#  ['Ghost', 'Grass'],
#  ['Ghost', 'Grass'],
#  ['Ghost', 'Grass'],
#  ['Ghost', 'Grass'],
#  ['Ghost', 'Grass'],
#  ['Ice', nan],
#  ['Ice', nan],
#  ['Flying', 'Dragon'],
#  ['Flying', 'Dragon'],
#  ['Fairy', nan],
#  ['Dark', 'Flying'],
#  ['Dragon', 'Ground'],
#  ['Rock', 'Fairy'],
#  ['Rock', 'Fairy'],
#  ['Psychic', 'Ghost'],
#  ['Psychic', 'Dark'],
#  ['Fire', 'Water']]

# %% [markdown]
# #### Cleanup `Name` that contain "Mega".
#
# If you have checked out the pokemon names carefully enough, you should have found there are junk texts in the pokemon names which contain "Mega". We want to clean up the pokemon names. For instance, "VenusaurMega Venusaur" should be "Mega Venusaur", and "CharizardMega Charizard X" should be "Mega Charizard X".

# %%
pattern="(.*)(Mega)"
result= "Mega"

pokemon['Name'] = pokemon['Name'].str.replace(pattern,result)
# Out:
# /var/folders/_z/gw3f_k0d08zctss1m54yb4pc0000gn/T/ipykernel_3184/2338511074.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   pokemon['Name'] = pokemon['Name'].str.replace(pattern,result)

# %%
# your code here


pokemon['Name'] = pokemon['Name'].str.replace(".*(Mega)", "")



#display(pokemon['Name'])
display(pokemon[pokemon['Name']=="Mega[\w']+"])

# test transformed data
# Out:
# /var/folders/_z/gw3f_k0d08zctss1m54yb4pc0000gn/T/ipykernel_3184/2834083126.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   pokemon['Name'] = pokemon['Name'].str.replace(".*(Mega)", "")
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3                 Venusaur
# 4               Charmander
#               ...
# 795                Diancie
# 796                Diancie
# 797    HoopaHoopa Confined
# 798     HoopaHoopa Unbound
# 799              Volcanion
# Name: Name, Length: 800, dtype: object
# Empty DataFrame
# Columns: [#, Name, Type 1, Type 2, Total, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation, Legendary]
# Index: []

# %% [markdown]
# #### Create a new column called `A/D Ratio` whose value equals to `Attack` devided by `Defense`.
#
# For instance, if a pokemon has the Attack score 49 and Defense score 49, the corresponding `A/D Ratio` is 49/49=1.

# %%
# your code here
pokemon['A/D Ratio'] = pokemon['Attack'] / pokemon['Defense']
pokemon.head(5)
# Out:
#    #           Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1      Bulbasaur  Grass  Poison    318  45      49       49       65
# 1  2        Ivysaur  Grass  Poison    405  60      62       63       80
# 2  3       Venusaur  Grass  Poison    525  80      82       83      100
# 3  3  Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4  4     Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  A/D Ratio
# 0       65     45           1      False   1.000000
# 1       80     60           1      False   0.984127
# 2      100     80           1      False   0.987952
# 3      120     80           1      False   0.813008
# 4       50     65           1      False   1.209302

# %% [markdown]
# #### Identify the pokemon with the highest `A/D Ratio`.

# %%
# your code here
pokemon[pokemon['A/D Ratio']==pokemon['A/D Ratio'].max()]
# Out:
#        #                Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 429  386  DeoxysAttack Forme  Psychic    NaN    600  50     180       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio
# 429      180       20    150           3       True        9.0

# %% [markdown]
# #### Identify the pokemon with the lowest A/D Ratio.

# %%
# your code here
pokemon[pokemon['A/D Ratio']==pokemon['A/D Ratio'].min()]
# Out:
#        #     Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 230  213  Shuckle    Bug   Rock    505  20      10      230       10      230
#
#      Speed  Generation  Legendary  A/D Ratio
# 230      5           2      False   0.043478

# %% [markdown]
# #### Create a new column called `Combo Type` whose value combines `Type 1` and `Type 2`.
#
# Rules:
#
# * If both `Type 1` and `Type 2` have valid values, the `Combo Type` value should contain both values in the form of `<Type 1> <Type 2>`. For example, if `Type 1` value is `Grass` and `Type 2` value is `Poison`, `Combo Type` will be `Grass-Poison`.
#
# * If `Type 1` has valid value but `Type 2` is not, `Combo Type` will be the same as `Type 1`. For example, if `Type 1` is `Fire` whereas `Type 2` is `NaN`, `Combo Type` will be `Fire`.

# %%
# your code here

def combine_type(row):
    if pd.isnull(row['Type 1']):
        return row['Type 2']
    elif pd.isnull(row['Type 2']):
        return row['Type 1']
    else:
        return str(str(row['Type 1'])+"_"+str(row['Type 2']))
    
pokemon['Combo Type'] = pokemon.apply(combine_type, axis=1)
pokemon.head()
# Out:
#    #           Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1      Bulbasaur  Grass  Poison    318  45      49       49       65
# 1  2        Ivysaur  Grass  Poison    405  60      62       63       80
# 2  3       Venusaur  Grass  Poison    525  80      82       83      100
# 3  3  Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4  4     Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  A/D Ratio    Combo Type
# 0       65     45           1      False   1.000000  Grass_Poison
# 1       80     60           1      False   0.984127  Grass_Poison
# 2      100     80           1      False   0.987952  Grass_Poison
# 3      120     80           1      False   0.813008  Grass_Poison
# 4       50     65           1      False   1.209302          Fire

# %% [markdown]
# #### Identify the pokemon whose `A/D Ratio` are among the top 5.

# %%
# your code here
#df.sort_values(by=['col1'])
pok_5=pokemon.sort_values(by=['A/D Ratio']).tail(5)

# %% [markdown]
# #### For the 5 pokemon printed above, aggregate `Combo Type` and use a list to store the unique values.
#
# Your end product is a list containing the distinct `Combo Type` values of the 5 pokemon with the highest `A/D Ratio`.

# %%
# your code here
lst_5_combo=list(pok_5['Combo Type'].unique())
print(lst_5_combo)
# Out:
# ['Psychic', 'Rock', 'Bug_Poison', 'Water_Dark']

# %% [markdown]
# #### For each of the `Combo Type` values obtained from the previous question, calculate the mean scores of all numeric fields across all pokemon.
#
# Your output should look like below:
#
# ![Aggregate](../images/aggregated-mean.png)

# %%
# your code here

pokemon[pokemon['Combo Type'].isin(lst_5_combo)].groupby('Combo Type').mean()
# Out:
#                      #       Total         HP      Attack     Defense  \
# Combo Type
# Bug_Poison  199.166667  347.916667  53.750000   68.333333   58.083333
# Psychic     381.973684  464.552632  72.552632   64.947368   67.236842
# Rock        410.111111  409.444444  67.111111  103.333333  107.222222
# Water_Dark  347.666667  493.833333  69.166667  120.000000   65.166667
#
#               Sp. Atk    Sp. Def      Speed  Generation  Legendary  A/D Ratio
# Combo Type
# Bug_Poison  42.500000  59.333333  65.916667    2.333333   0.000000   1.315989
# Psychic     98.552632  82.394737  78.868421    3.342105   0.236842   1.164196
# Rock        40.555556  58.333333  32.888889    3.888889   0.111111   1.260091
# Water_Dark  88.833333  63.500000  87.166667    3.166667   0.000000   2.291949
